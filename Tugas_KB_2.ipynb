# %% [markdown]
# <a href="https://colab.research.google.com/github/RahmadARDgMatutu/Tugas-KB-2/blob/main/Tugas_KB_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import warnings
warnings.filterwarnings('ignore')

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn import metrics

# %%
cc = pd.read_csv('diabetes.csv')
cc.head(10)
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
# 5            5      116             74              0        0  25.6
# 6            3       78             50             32       88  31.0
# 7           10      115              0              0        0  35.3
# 8            2      197             70             45      543  30.5
# 9            8      125             96              0        0   0.0
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# ...

# %%
cc.tail(10)
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 758            1      106             76              0        0  37.5
# 759            6      190             92              0        0  35.5
# 760            2       88             58             26       16  28.4
# 761            9      170             74             31        0  44.0
# 762            9       89             62              0        0  22.5
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 758                     0.197   26        0
# 759                     0.278   66        1
# 760                     0.766   22        0
# ...

# %%
cc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               768 non-null    int64
#  1   Glucose                   768 non-null    int64
#  2   BloodPressure             768 non-null    int64
#  3   SkinThickness             768 non-null    int64
#  4   Insulin                   768 non-null    int64
#  5   BMI                       768 non-null    float64
#  6   DiabetesPedigreeFunction  768 non-null    float64
#  7   Age                       768 non-null    int64
#  8   Outcome                   768 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %%
cc.sample(10)
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 552            6      114             88              0        0  27.8
# 345            8      126             88             36      108  38.5
# 537            0       57             60              0        0  21.7
# 102            0      125             96              0        0  22.5
# 52             5       88             66             21       23  24.4
# 191            9      123             70             44       94  33.1
# 360            5      189             64             33      325  31.2
# 170            6      102             82              0        0  30.8
# 481            0      123             88             37        0  35.2
# 107            4      144             58             28      140  29.5
#
#      DiabetesPedigreeFunction  Age  Outcome
# 552                     0.247   66        0
# 345                     0.349   49        0
# 537                     0.735   67        0
# ...

# %%
cc.shape
# Out:
# (768, 9)

# %%
cc.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# ...

# %%
cc.shape
# Out:
# (768, 9)

# %%
cc.isnull().sum()
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %%
cc.columns
# Out:
# Index(['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin',
#        'BMI', 'DiabetesPedigreeFunction', 'Age', 'Outcome'],
#       dtype='object')

# %%
#Data Preprocessing
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=5)

# %%
X_train.shape
# Out:
# (614, 8)

# %%
y_train.shape
# Out:
# (614,)

# %%
X_test.shape
# Out:
# (154, 8)

# %%
y_test.shape
# Out:
# (154,)

# %%
#Create A SVM classifier
from sklearn import svm

classifier = svm.SVC(kernel='linear',gamma='auto',C=2)

#Training the Model
classifier.fit(X_train,y_train)

#Predict Model
y_predict=classifier.predict(X_test)

# %%
print('Accuracy : ',metrics.accuracy_score(y_true=y_test, y_pred=y_predict))
# Out:
# Accuracy :  0.7987012987012987

# %%
print('precision : ',metrics.precision_score(y_true=y_test, y_pred=y_predict))
# Out:
# precision :  0.7446808510638298

# %%
print('Recall : ',metrics.recall_score(y_true=y_test, y_pred=y_predict))
# Out:
# Recall :  0.6481481481481481
